# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Gabriel Schlosberg__
# Data scientist

# %% [markdown]
# _I am interested in data science because it fasinates me that you can take something seemingly useless - such as unstructured, disorganised, or irrelevant data, and find within it an intricate web of connections that were invisible before, and use that web to benefit people._

# %% [markdown]
# ### Print the text

# %%
print("Hello, reader.")
# Out:
# Hello, reader.

# %% [markdown]
# Here's a hyperlink: [https://www.youtube.com/watch?v=dQw4w9WgXcQ]
#
# 1. This
# 2. Is
# 3. My
# 4. Numbered
# 5. List
#     1. This is
#     2. My sub list
#
# Text above a horizontal separator
# ***
# Text below a horizontal separator
#
# [~~~strikethrough text is cool~~~]
